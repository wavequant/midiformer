# %%
# !python 01_prepare_dataset.py
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# --- Step 1: Filtering and Standardizing MIDI Files ---
# INFO: Loading data splits from maestro_midi_data/maestro-v3.0.0.csv...
# INFO: Found 94 train, 13 validation, and 18 test files.
# INFO: Processing training files to build vocabulary...
# ...

# %%
# !python 00_verify_dataset.py
# Out:
# --- Running Dataset Verification Script ---
# INFO: Loading data from 'data/tokenized_maestro.pkl'...
# INFO: File loaded successfully.
#
# --- Verifying Data Structure ---
# INFO: Found main keys: ['event_to_int', 'int_to_event', 'train_tokens', 'validation_tokens', 'test_tokens']
# INFO: Data structure looks correct.
#
# --- Verifying Vocabulary ---
# INFO: Vocabulary size: 440
# INFO: Checking first 10 vocabulary mappings:
#   Token 0 -> '<pad>'
#   Token 1 -> '<unk>'
#   Token 2 -> 'time_shift_1'
#   Token 3 -> 'time_shift_2'
#   Token 4 -> 'time_shift_3'
#   Token 5 -> 'time_shift_4'
#   Token 6 -> 'time_shift_5'
#   Token 7 -> 'velocity_17'
#   Token 8 -> 'velocity_18'
#   Token 9 -> 'velocity_16'
# WARNING: Vocabulary size (440) does not match config.py (512). This is okay if intentional.
#
# --- Verifying Token Streams ---
#
# -- Checking 'train' split --
# INFO: Total number of tokens: 3,028,834
# INFO: Raw token snippet (first 20 tokens):
# ...

# %%
# !python 01_prepare_dataset.py
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# --- Step 1: Filtering and Standardizing MIDI Files ---
# INFO: Loading data splits from maestro_midi_data/maestro-v3.0.0.csv...
# INFO: Found 962 train, 137 validation, and 177 test files.
# INFO: Processing training files to build vocabulary...
# ...

# %%
# !python 03_generate.py models/best_model_step_11776.pt
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# --- Starting Music Generation ---
# INFO: Using device: mps
# INFO: Loading vocabulary from data/tokenized_maestro.pkl
# INFO: Loading model from models/best_model_step_11776.pt
# INFO: Generating 1024 tokens with seed: ['note_on_60', 'velocity_20']
# Generating Tokens: 100%|████████████████████| 1024/1024 [00:44<00:00, 22.86it/s]
# INFO: MIDI file saved to generated_music/output.mid
#
# --- Generation Complete ---
#
# To play the generated MIDI file on macOS, you can use:
# 1. QuickTime Player: Simply open the .mid file.
# 2. GarageBand: Drag and drop the file into a new project to see the notes and assign instruments.

# %%
# !python 03_generate.py models/best_model_step_256.pt
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# --- Starting Music Generation ---
# INFO: Using device: mps
# INFO: Loading vocabulary from data/tokenized_maestro.pkl
# INFO: Loading model from models/best_model_step_256.pt
# INFO: Generating 1024 tokens with seed: ['note_on_60', 'velocity_20']
# Generating Tokens: 100%|████████████████████| 1024/1024 [00:39<00:00, 26.03it/s]
# INFO: MIDI file saved to generated_music/output.mid
#
# --- Generation Complete ---
#
# To play the generated MIDI file on macOS, you can use:
# 1. QuickTime Player: Simply open the .mid file.
# 2. GarageBand: Drag and drop the file into a new project to see the notes and assign instruments.

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 144 --seed_length 256 --beam_size 3 --block_ngrams 2 --num_tokens 1568
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 144.
# Информация: Използваме сийд файл: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с beam search, k=3): 100%|███████| 1568/1568 [00:45<00:00, 34.41it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_144_beam_3_ngram_2.mid
#
# ...
# --- Готово ---

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 154 --seed_length 512 --beam_size 0 --temperature 1.4 --num_tokens 2048
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 154.
# Информация: Използваме сийд файл: MIDI-UNPROCESSED_11-13_R1_2014_MID--AUDIO_13_R1_2014_wav--4.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с top-k семплиране: 100%|███████| 2048/2048 [00:17<00:00, 117.07it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_154_topk_20_temp_1.4.mid
#
# ...
# --- Готово ---

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 144 --seed_length 256 --beam_size 0 --temperature 1.04 --num_tokens 4096
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 144.
# Информация: Използваме сийд файл: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с top-k семплиране: 100%|████████| 4096/4096 [00:48<00:00, 84.95it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_144_topk_20_temp_1.04.mid
#
# ...
# --- Готово ---

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 144 --seed_length 256 --beam_size 0 --temperature 1.01 --num_tokens 4096
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 144.
# Информация: Използваме сийд файл: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с top-k семплиране: 100%|████████| 4096/4096 [00:48<00:00, 83.74it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_144_topk_20_temp_1.01.mid
#
# ...
# --- Готово ---

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 144 --seed_length 256 --beam_size 0 --temperature 0.98 --num_tokens 4096
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 144.
# Информация: Използваме сийд файл: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с top-k семплиране: 100%|████████| 4096/4096 [00:48<00:00, 84.38it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_144_topk_20_temp_0.98.mid
#
# ...
# --- Готово ---

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 144 --seed_length 256 --beam_size 0 --temperature 0.95 --num_tokens 4096
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 144.
# Информация: Използваме сийд файл: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с top-k семплиране: 100%|████████| 4096/4096 [00:48<00:00, 84.06it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_144_topk_20_temp_0.95.mid
#
# ...
# --- Готово ---

# %%
# !python 03_generate.py models4/best_model_step_36096.pt --test_seed_index 144 --seed_length 256 --beam_size 0 --temperature 0.92 --num_tokens 4096
# Out:
# /Users/darin/Python Projects/MUSICGEN/env/lib/python3.12/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
# Информация: Сийдваме генерацията с тестов файл с пореден номер 144.
# Информация: Използваме сийд файл: MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#
# ...
# --- Ползвам модел: best_model_step_36096.pt ---
# Генериране с top-k семплиране: 100%|████████| 4096/4096 [00:48<00:00, 83.81it/s]
# Информация: МИДИ файлове запазени в generated_music/best_model_step_36096_seed_144_topk_20_temp_0.92.mid
#
# ...
# --- Готово ---

# %% [markdown]
# ## NEW QUANTIZATION

# %%
# !python 02_train.py
# Out:
# wandb: Currently logged in as: wavequant (wavequant-insait) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.20.1
# wandb: Run data is saved locally in /Users/darin/Python Projects/MUSICGEN/wandb/run-20250615_020748-k2n2qhc6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run royal-water-7
# wandb: ⭐️ View project at https://wandb.ai/wavequant-insait/music-transformer-project
# wandb: 🚀 View run at https://wandb.ai/wavequant-insait/music-transformer-project/runs/k2n2qhc6
# --- Обучение ---
# Информация: Моделът е зареден на mps
# Информация: Зареждам данните от data/tokenized_maestro.pkl
# Информация: Моделът е инициализиран с 13,141,504 параметъра.
# ...
